# %% [markdown]
# <a href="https://colab.research.google.com/github/VanshShah98/Weather-analyzer/blob/main/Weateher_Analyser.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

weather = pd.read_csv("3467653.csv", index_col="DATE")

# %%
weather
# Out:
#                 STATION                              NAME   AWND    FMTM  \
# DATE
# 2000-01-01  USW00094789  JFK INTERNATIONAL AIRPORT, NY US   7.38  1545.0
# 2000-01-02  USW00094789  JFK INTERNATIONAL AIRPORT, NY US   7.61  1826.0
# 2000-01-03  USW00094789  JFK INTERNATIONAL AIRPORT, NY US   3.13  1045.0
# 2000-01-04  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  14.54  1841.0
# 2000-01-05  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  17.67   851.0
# ...                 ...                               ...    ...     ...
# 2023-09-19  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  11.86     NaN
# 2023-09-20  USW00094789  JFK INTERNATIONAL AIRPORT, NY US   8.72     NaN
# 2023-09-21  USW00094789  JFK INTERNATIONAL AIRPORT, NY US   7.16     NaN
# 2023-09-22  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  13.20     NaN
# 2023-09-23  USW00094789  JFK INTERNATIONAL AIRPORT, NY US    NaN     NaN
#
#               PGTM  PRCP  SNOW  SNWD  TAVG  TMAX  ...  WT13  WT14  WT15  WT16  \
# ...

# %%
null_pct = weather.apply(pd.isnull).sum()/weather.shape[0]
null_pct
# Out:
# station    0.0
# name       0.0
# awnd       0.0
# prcp       0.0
# snow       0.0
# snwd       0.0
# tmax       0.0
# tmin       0.0
# wdf2       0.0
# wdf5       0.0
# wsf2       0.0
# wsf5       0.0
# target     0.0
# dtype: float64

# %%
valid_columns = weather.columns[null_pct < .05]
valid_columns
weather = weather[valid_columns].copy()

# %%
weather.columns = weather.columns.str.lower()

# %%
weather
# Out:
#                 station                              name   awnd  prcp  snow  \
# DATE
# 2000-01-01  USW00094789  JFK INTERNATIONAL AIRPORT, NY US   7.38  0.00   0.0
# 2000-01-02  USW00094789  JFK INTERNATIONAL AIRPORT, NY US   7.61  0.00   0.0
# 2000-01-03  USW00094789  JFK INTERNATIONAL AIRPORT, NY US   3.13  0.00   0.0
# 2000-01-04  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  14.54  0.62   0.0
# 2000-01-05  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  17.67  0.04   0.0
# ...                 ...                               ...    ...   ...   ...
# 2023-09-19  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  11.86  0.00   0.0
# 2023-09-20  USW00094789  JFK INTERNATIONAL AIRPORT, NY US   8.72  0.00   0.0
# 2023-09-21  USW00094789  JFK INTERNATIONAL AIRPORT, NY US   7.16  0.00   0.0
# 2023-09-22  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  13.20  0.00   0.0
# 2023-09-23  USW00094789  JFK INTERNATIONAL AIRPORT, NY US    NaN  0.96   0.0
#
# ...

# %%
weather = weather.ffill()

# %%
import seaborn as sns
weather.apply(pd.isnull).sum()
sns.heatmap(weather.isnull())
# Out:
# <Axes: ylabel='DATE'>

# %%
weather.apply(lambda x: (x == 9999).sum())
# Out:
# station    0
# name       0
# awnd       0
# prcp       0
# snow       0
# snwd       0
# tmax       0
# tmin       0
# wdf2       0
# wdf5       0
# wsf2       0
# wsf5       0
# dtype: int64

# %%
weather.dtypes
# Out:
# station     object
# name        object
# awnd       float64
# prcp       float64
# snow       float64
# snwd       float64
# tmax         int64
# tmin         int64
# wdf2       float64
# wdf5       float64
# wsf2       float64
# wsf5       float64
# target     float64
# dtype: object

# %%
weather.index
# Out:
# Index(['2000-01-01', '2000-01-02', '2000-01-03', '2000-01-04', '2000-01-05',
#        '2000-01-06', '2000-01-07', '2000-01-08', '2000-01-09', '2000-01-10',
#        ...
#        '2023-09-14', '2023-09-15', '2023-09-16', '2023-09-17', '2023-09-18',
#        '2023-09-19', '2023-09-20', '2023-09-21', '2023-09-22', '2023-09-23'],
#       dtype='object', name='DATE', length=8667)

# %%
weather.index = pd.to_datetime(weather.index)
weather.index.year.value_counts().sort_index()
# Out:
# 2000    366
# 2001    365
# 2002    365
# 2003    365
# 2004    366
# 2005    365
# 2006    365
# 2007    365
# 2008    366
# 2009    365
# 2010    365
# 2011    365
# 2012    366
# 2013    365
# 2014    365
# 2015    365
# 2016    366
# 2017    365
# 2018    365
# 2019    365
# 2020    366
# 2021    365
# 2022    365
# 2023    266
# Name: DATE, dtype: int64

# %%
weather["snwd"].plot()
weather["tmax"].plot()
weather["tmin"].plot()
weather["awnd"].plot()
weather["prcp"].plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
weather["target"] = weather.shift(-1)["tmax"]
weather
# Out:
#                 station                              name   awnd  prcp  snow  \
# DATE
# 2000-01-01  USW00094789  JFK INTERNATIONAL AIRPORT, NY US   7.38  0.00   0.0
# 2000-01-02  USW00094789  JFK INTERNATIONAL AIRPORT, NY US   7.61  0.00   0.0
# 2000-01-03  USW00094789  JFK INTERNATIONAL AIRPORT, NY US   3.13  0.00   0.0
# 2000-01-04  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  14.54  0.62   0.0
# 2000-01-05  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  17.67  0.04   0.0
# ...                 ...                               ...    ...   ...   ...
# 2023-09-19  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  11.86  0.00   0.0
# 2023-09-20  USW00094789  JFK INTERNATIONAL AIRPORT, NY US   8.72  0.00   0.0
# 2023-09-21  USW00094789  JFK INTERNATIONAL AIRPORT, NY US   7.16  0.00   0.0
# 2023-09-22  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  13.20  0.00   0.0
# 2023-09-23  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  13.20  0.96   0.0
#
# ...

# %%
weather = weather.ffill()
weather
# Out:
#                 station                              name   awnd  prcp  snow  \
# DATE
# 2000-01-01  USW00094789  JFK INTERNATIONAL AIRPORT, NY US   7.38  0.00   0.0
# 2000-01-02  USW00094789  JFK INTERNATIONAL AIRPORT, NY US   7.61  0.00   0.0
# 2000-01-03  USW00094789  JFK INTERNATIONAL AIRPORT, NY US   3.13  0.00   0.0
# 2000-01-04  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  14.54  0.62   0.0
# 2000-01-05  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  17.67  0.04   0.0
# ...                 ...                               ...    ...   ...   ...
# 2023-09-19  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  11.86  0.00   0.0
# 2023-09-20  USW00094789  JFK INTERNATIONAL AIRPORT, NY US   8.72  0.00   0.0
# 2023-09-21  USW00094789  JFK INTERNATIONAL AIRPORT, NY US   7.16  0.00   0.0
# 2023-09-22  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  13.20  0.00   0.0
# 2023-09-23  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  13.20  0.96   0.0
#
# ...

# %% [markdown]
# Analysis:
#
# Over this period, the daily maximum and minimum temperatures have shown typical seasonal variations, with higher temperatures in the summer months and lower temperatures in the winter months.
# The average daily temperature appears to range from about 3.13°F to 17.67°F, with variations depending on the time of the year.
# Precipitation Analysis:
#
# Precipitation data indicates that there have been periods of both rainfall and snowfall.
# The data suggests that some days have recorded no precipitation (0.00 inches), while others have experienced small amounts of rainfall and snowfall (e.g., 0.04 inches).
# Deeper analysis is required to identify long-term trends, such as increasing or decreasing precipitation over the years.
# Wind Analysis:
#
# Wind data includes both wind speed and direction. Wind speeds appear to vary, with occasional high wind speeds (e.g., 31.1 mph).
# Wind direction fluctuates, indicating variability in wind patterns, which is typical in weather patterns.
# Humidity Analysis:
#
# Relative humidity data provides information on moisture levels in the air, which can vary over the years and seasons. Further analysis is needed to identify any specific patterns or trends.
# Barometric Pressure Analysis:
#
# The data shows fluctuations in barometric pressure, which can be used to monitor changes in atmospheric conditions. However, a more detailed analysis is necessary to interpret these fluctuations in a meaningful way.
# Conclusion:
#
# The provided data offers a snapshot of daily weather conditions at JFK International Airport. While this analysis highlights some general trends and variations, more in-depth analysis is required to draw comprehensive conclusions about long-term weather patterns, climate change, or specific impacts on airport operations.
